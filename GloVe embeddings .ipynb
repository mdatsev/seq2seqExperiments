# %%
import pickle

with open('./articles.p', 'rb') as fp:
    heds, contents = pickle.load(fp)

# %%
from collections import Counter
from itertools import chain

# %%
import re
import nltk
all_text = " ".join(heds + contents).replace(".", " . ")
tokenized_words = nltk.word_tokenize(all_text)
vocabcount = Counter(word.strip() for word in tokenized_words)
vocab = map(lambda x: x[0], sorted(vocabcount.items(), key=lambda x: -x[1]))

# %%
#list(vocab)

# %%
len(vocabcount)
# Out:
# 14100

# %%
glove_vec_size = 100
fname = 'glove.6B.%d.txt'%glove_vec_size
import os
start = 2

# %%
word2idx = dict((word, i+start) for i,word in enumerate(vocab))

# %%
word2idx
# Out:
# {'.': 2,
#  'the': 3,
#  ',': 4,
#  'to': 5,
#  'of': 6,
#  'in': 7,
#  'a': 8,
#  'and': 9,
#  "'s": 10,
#  '``': 11,
#  'The': 12,
#  'said': 13,
#  'is': 14,
#  'for': 15,
#  'that': 16,
#  'on': 17,
#  '%': 18,
#  'has': 19,
#  "''": 20,
#  'it': 21,
#  'by': 22,
#  'its': 23,
#  'was': 24,
#  'with': 25,
#  'as': 26,
#  'at': 27,
#  '$': 28,
#  'be': 29,
#  'from': 30,
#  'have': 31,
#  'are': 32,
#  'US': 33,
#  'will': 34,
#  '-': 35,
#  'year': 36,
#  'Mr': 37,
#  'which': 38,
#  'an': 39,
#  '(': 40,
#  ')': 41,
#  'had': 42,
#  'not': 43,
#  'would': 44,
#  'been': 45,
#  'than': 46,
#  'more': 47,
#  'also': 48,
#  'up': 49,
#  'were': 50,
#  'market': 51,
#  'company': 52,
#  'this': 53,
#  'their': 54,
#  'growth': 55,
#  'firm': 56,
#  'economy': 57,
#  'about': 58,
#  'he': 59,
#  '1': 60,
#  'but': 61,
#  'government': 62,
#  'It': 63,
#  'new': 64,
#  'last': 65,
#  'could': 66,
#  '2004': 67,
#  'after': 68,
#  'sales': 69,
#  'economic': 70,
#  'over': 71,
#  'In': 72,
#  'oil': 73,
#  'But': 74,
#  'they': 75,
#  'years': 76,
#  '2': 77,
#  'prices': 78,
#  "'": 79,
#  'chief': 80,
#  'China': 81,
#  'two': 82,
#  'may': 83,
#  'now': 84,
#  'one': 85,
#  'UK': 86,
#  'we': 87,
#  'deal': 88,
#  'shares': 89,
#  'rise': 90,
#  'business': 91,
#  'out': 92,
#  '5': 93,
#  'Bank': 94,
#  'companies': 95,
#  'expected': 96,
#  '3': 97,
#  'Yukos': 98,
#  'A': 99,
#  'world': 100,
#  'or': 101,
#  'who': 102,
#  'However': 103,
#  'into': 104,
#  '2005': 105,
#  '4': 106,
#  'firms': 107,
#  'his': 108,
#  'some': 109,
#  'dollar': 110,
#  'December': 111,
#  'country': 112,
#  'while': 113,
#  'months': 114,
#  'against': 115,
#  'other': 116,
#  'since': 117,
#  'people': 118,
#  'if': 119,
#  'still': 120,
#  'rate': 121,
#  'European': 122,
#  'time': 123,
#  'told': 124,
#  'there': 125,
#  '2003': 126,
#  'first': 127,
#  'India': 128,
#  'We': 129,
#  'financial': 130,
#  'demand': 131,
#  'all': 132,
#  'quarter': 133,
#  'down': 134,
#  'made': 135,
#  'between': 136,
#  'countries': 137,
#  'rates': 138,
#  'interest': 139,
#  'such': 140,
#  'figures': 141,
#  'investment': 142,
#  'executive': 143,
#  'three': 144,
#  'biggest': 145,
#  'month': 146,
#  'any': 147,
#  'spending': 148,
#  'profits': 149,
#  'price': 150,
#  'many': 151,
#  'Europe': 152,
#  'state': 153,
#  'when': 154,
#  'added': 155,
#  'bank': 156,
#  'group': 157,
#  '0': 158,
#  'jobs': 159,
#  '8': 160,
#  'tax': 161,
#  'offer': 162,
#  'back': 163,
#  '6': 164,
#  'euros': 165,
#  'strong': 166,
#  'rose': 167,
#  'bid': 168,
#  'much': 169,
#  'can': 170,
#  'trade': 171,
#  'costs': 172,
#  'set': 173,
#  'money': 174,
#  'stock': 175,
#  'no': 176,
#  'analysts': 177,
#  'I': 178,
#  ';': 179,
#  'only': 180,
#  'most': 181,
#  'January': 182,
#  'foreign': 183,
#  'increase': 184,
#  'next': 185,
#  'should': 186,
#  'part': 187,
#  'cut': 188,
#  '&': 189,
#  'fall': 190,
#  'share': 191,
#  'budget': 192,
#  'million': 193,
#  'hit': 194,
#  'make': 195,
#  '10': 196,
#  'week': 197,
#  'our': 198,
#  'London': 199,
#  'recent': 200,
#  'He': 201,
#  'high': 202,
#  'Russian': 203,
#  'well': 204,
#  'Japan': 205,
#  'do': 206,
#  'move': 207,
#  'take': 208,
#  'Deutsche': 209,
#  'under': 210,
#  'industry': 211,
#  'says': 212,
#  'during': 213,
#  'being': 214,
#  'debt': 215,
#  'United': 216,
#  'likely': 217,
#  'pay': 218,
#  'report': 219,
#  'production': 220,
#  '7': 221,
#  'fell': 222,
#  'This': 223,
#  'higher': 224,
#  'reported': 225,
#  'deficit': 226,
#  'former': 227,
#  'annual': 228,
#  'say': 229,
#  'Russia': 230,
#  'investors': 231,
#  'sale': 232,
#  'President': 233,
#  'because': 234,
#  'news': 235,
#  'court': 236,
#  'EU': 237,
#  'bankruptcy': 238,
#  'just': 239,
#  'number': 240,
#  'continue': 241,
#  'further': 242,
#  'off': 243,
#  'cost': 244,
#  'plans': 245,
#  'New': 246,
#  '9': 247,
#  'record': 248,
#  'main': 249,
#  'November': 250,
#  'exports': 251,
#  'public': 252,
#  'seen': 253,
#  'case': 254,
#  'end': 255,
#  'giant': 256,
#  'future': 257,
#  'South': 258,
#  'profit': 259,
#  'unit': 260,
#  'markets': 261,
#  'less': 262,
#  'both': 263,
#  'Analysts': 264,
#  'largest': 265,
#  'boost': 266,
#  ':': 267,
#  'too': 268,
#  'trading': 269,
#  'statement': 270,
#  'fraud': 271,
#  'euro': 272,
#  'consumer': 273,
#  'need': 274,
#  'sector': 275,
#  'car': 276,
#  'lost': 277,
#  '5bn': 278,
#  'agreed': 279,
#  'German': 280,
#  'work': 281,
#  'meeting': 282,
#  'already': 283,
#  'GM': 284,
#  'before': 285,
#  'so': 286,
#  'put': 287,
#  'according': 288,
#  'shareholders': 289,
#  "n't": 290,
#  'LSE': 291,
#  'stake': 292,
#  'low': 293,
#  'takeover': 294,
#  'buy': 295,
#  'global': 296,
#  'value': 297,
#  'decision': 298,
#  'earlier': 299,
#  'warned': 300,
#  'including': 301,
#  'came': 302,
#  'saying': 303,
#  'see': 304,
#  'club': 305,
#  'previous': 306,
#  'domestic': 307,
#  'help': 308,
#  'current': 309,
#  'through': 310,
#  'banks': 311,
#  'Tuesday': 312,
#  'Gazprom': 313,
#  'past': 314,
#  'airline': 315,
#  'October': 316,
#  'analyst': 317,
#  'them': 318,
#  'latest': 319,
#  'did': 320,
#  'get': 321,
#  'Fiat': 322,
#  'total': 323,
#  'talks': 324,
#  'good': 325,
#  'very': 326,
#  'announced': 327,
#  '30': 328,
#  'board': 329,
#  'second': 330,
#  'earnings': 331,
#  'way': 332,
#  'economist': 333,
#  'key': 334,
#  'five': 335,
#  'There': 336,
#  'Bush': 337,
#  'period': 338,
#  'major': 339,
#  'sold': 340,
#  'products': 341,
#  'Boerse': 342,
#  'Indian': 343,
#  'own': 344,
#  'president': 345,
#  'top': 346,
#  '20': 347,
#  'Friday': 348,
#  'Commission': 349,
#  'fuel': 350,
#  'level': 351,
#  'data': 352,
#  'Glazer': 353,
#  'Thursday': 354,
#  'Group': 355,
#  'where': 356,
#  'output': 357,
#  'ahead': 358,
#  'lower': 359,
#  'however': 360,
#  'September': 361,
#  'half': 362,
#  'recovery': 363,
#  'Ebbers': 364,
#  'reports': 365,
#  'exchange': 366,
#  'They': 367,
#  'agreement': 368,
#  'those': 369,
#  'what': 370,
#  'operations': 371,
#  'Asia': 372,
#  'assets': 373,
#  'York': 374,
#  'bought': 375,
#  'following': 376,
#  'Exchange': 377,
#  'On': 378,
#  'remain': 379,
#  'due': 380,
#  'going': 381,
#  '12': 382,
#  'index': 383,
#  'impact': 384,
#  'charges': 385,
#  'director': 386,
#  'close': 387,
#  'Germany': 388,
#  'go': 389,
#  'despite': 390,
#  'far': 391,
#  'how': 392,
#  'even': 393,
#  '15': 394,
#  'France': 395,
#  'increased': 396,
#  'gas': 397,
#  'inflation': 398,
#  'plan': 399,
#  'Reuters': 400,
#  'forecast': 401,
#  'Shares': 402,
#  'finance': 403,
#  'Yugansk': 404,
#  'ВЈ1': 405,
#  'come': 406,
#  'support': 407,
#  'early': 408,
#  'face': 409,
#  'Japanese': 410,
#  'cash': 411,
#  'development': 412,
#  '1bn': 413,
#  'control': 414,
#  'World': 415,
#  'legal': 416,
#  'result': 417,
#  'Rosneft': 418,
#  'law': 419,
#  'these': 420,
#  'same': 421,
#  'currently': 422,
#  'businesses': 423,
#  'spokesman': 424,
#  'action': 425,
#  'IMF': 426,
#  'four': 427,
#  'manufacturing': 428,
#  'currency': 429,
#  '3bn': 430,
#  'workers': 431,
#  'believe': 432,
#  'Monday': 433,
#  'Wednesday': 434,
#  'corporate': 435,
#  'rising': 436,
#  'America': 437,
#  'accounts': 438,
#  'big': 439,
#  'private': 440,
#  'does': 441,
#  '4bn': 442,
#  'job': 443,
#  'house': 444,
#  '11': 445,
#  'chairman': 446,
#  'making': 447,
#  'below': 448,
#  'As': 449,
#  'whether': 450,
#  'until': 451,
#  'insurance': 452,
#  'credit': 453,
#  'cuts': 454,
#  'third': 455,
#  'unemployment': 456,
#  'leading': 457,
#  'found': 458,
#  '2002': 459,
#  'retail': 460,
#  'few': 461,
#  'MCI': 462,
#  'remains': 463,
#  'around': 464,
#  'customers': 465,
#  'almost': 466,
#  'And': 467,
#  '2001': 468,
#  'minister': 469,
#  'long': 470,
#  'Chinese': 471,
#  'BBC': 472,
#  'then': 473,
#  'day': 474,
#  'average': 475,
#  'policy': 476,
#  'property': 477,
#  'order': 478,
#  'revenues': 479,
#  'account': 480,
#  'agency': 481,
#  'At': 482,
#  'use': 483,
#  'levels': 484,
#  'executives': 485,
#  'rules': 486,
#  'aid': 487,
#  'SEC': 488,
#  'better': 489,
#  'energy': 490,
#  'auction': 491,
#  '25': 492,
#  'growing': 493,
#  'results': 494,
#  'saw': 495,
#  'think': 496,
#  'start': 497,
#  'possible': 498,
#  'ago': 499,
#  'meet': 500,
#  'rival': 501,
#  'staff': 502,
#  '8bn': 503,
#  'forced': 504,
#  'performance': 505,
#  'If': 506,
#  'protection': 507,
#  'political': 508,
#  'According': 509,
#  'large': 510,
#  'best': 511,
#  'although': 512,
#  'survey': 513,
#  'problems': 514,
#  'Boeing': 515,
#  '6bn': 516,
#  'housing': 517,
#  'Securities': 518,
#  'taking': 519,
#  'international': 520,
#  'compared': 521,
#  'Financial': 522,
#  'Last': 523,
#  'like': 524,
#  'led': 525,
#  'give': 526,
#  'Iraq': 527,
#  'competition': 528,
#  'Minister': 529,
#  'services': 530,
#  'taken': 531,
#  'officials': 532,
#  'took': 533,
#  'product': 534,
#  'least': 535,
#  '2006': 536,
#  'look': 537,
#  'across': 538,
#  'French': 539,
#  'change': 540,
#  '2bn': 541,
#  'News': 542,
#  'Christmas': 543,
#  'fourth': 544,
#  'among': 545,
#  'International': 546,
#  'Ms': 547,
#  'authorities': 548,
#  'another': 549,
#  'claims': 550,
#  'Its': 551,
#  'target': 552,
#  'given': 553,
#  'become': 554,
#  'used': 555,
#  'figure': 556,
#  'claim': 557,
#  'banking': 558,
#  'above': 559,
#  'WorldCom': 560,
#  'hold': 561,
#  '50': 562,
#  'trillion': 563,
#  'needed': 564,
#  'February': 565,
#  'enough': 566,
#  'showed': 567,
#  'England': 568,
#  'crude': 569,
#  'confidence': 570,
#  'Sri': 571,
#  'Stock': 572,
#  'maker': 573,
#  'helped': 574,
#  'keep': 575,
#  'yet': 576,
#  'having': 577,
#  'nations': 578,
#  'raise': 579,
#  'Union': 580,
#  'later': 581,
#  'recently': 582,
#  'senior': 583,
#  'general': 584,
#  'accounting': 585,
#  'mortgage': 586,
#  'Air': 587,
#  'sell': 588,
#  'fund': 589,
#  'decline': 590,
#  'GDP': 591,
#  'previously': 592,
#  'include': 593,
#  'creditors': 594,
#  'British': 595,
#  'March': 596,
#  'rather': 597,
#  'days': 598,
#  'create': 599,
#  'significant': 600,
#  'loss': 601,
#  'consumers': 602,
#  'risk': 603,
#  'accused': 604,
#  'Khodorkovsky': 605,
#  'Standard': 606,
#  'slowdown': 607,
#  'Turkey': 608,
#  'run': 609,
#  'losses': 610,
#  'point': 611,
#  'closed': 612,
#  'That': 613,
#  'called': 614,
#  'pressure': 615,
#  'taxes': 616,
#  'American': 617,
#  'term': 618,
#  'concerns': 619,
#  'head': 620,
#  'hopes': 621,
#  'held': 622,
#  'looking': 623,
#  'focus': 624,
#  'Some': 625,
#  'comes': 626,
#  'worth': 627,
#  'areas': 628,
#  'trying': 629,
#  'affected': 630,
#  'telecoms': 631,
#  'cars': 632,
#  'poor': 633,
#  'show': 634,
#  'Korea': 635,
#  'Euronext': 636,
#  'conditions': 637,
#  'yen': 638,
#  'Sunday': 639,
#  'huge': 640,
#  '100': 641,
#  'little': 642,
#  'mobile': 643,
#  'Marsh': 644,
#  'members': 645,
#  'Lanka': 646,
#  'you': 647,
#  'airlines': 648,
#  'For': 649,
#  'grew': 650,
#  'revenue': 651,
#  'administration': 652,
#  'means': 653,
#  'National': 654,
#  'official': 655,
#  'want': 656,
#  'within': 657,
#  'home': 658,
#  'Street': 659,
#  'six': 660,
#  'net': 661,
#  'management': 662,
#  'paid': 663,
#  'national': 664,
#  'Despite': 665,
#  '16': 666,
#  'income': 667,
#  'BMW': 668,
#  'grow': 669,
#  'evidence': 670,
#  'Africa': 671,
#  'facing': 672,
#  'amount': 673,
#  'reached': 674,
#  '7bn': 675,
#  'goods': 676,
#  'Department': 677,
#  'signed': 678,
#  'coming': 679,
#  'benefits': 680,
#  '18': 681,
#  'working': 682,
#  'selling': 683,
#  'overall': 684,
#  'dropped': 685,
#  'proposals': 686,
#  'slow': 687,
#  'lending': 688,
#  'power': 689,
#  'trial': 690,
#  'once': 691,
#  'Indonesia': 692,
#  '2000': 693,
#  'expectations': 694,
#  'highest': 695,
#  'Federal': 696,
#  'late': 697,
#  'fallen': 698,
#  'per': 699,
#  'must': 700,
#  'falling': 701,
#  'officer': 702,
#  'line': 703,
#  'potential': 704,
#  'loans': 705,
#  'Sullivan': 706,
#  'central': 707,
#  'May': 708,
#  'election': 709,
#  'turn': 710,
#  'funds': 711,
#  'forecasts': 712,
#  'leaders': 713,
#  'expects': 714,
#  'dollars': 715,
#  'each': 716,
#  'adding': 717,
#  'activity': 718,
#  'she': 719,
#  'Italian': 720,
#  'continued': 721,
#  'economists': 722,
#  'While': 723,
#  'return': 724,
#  'S': 725,
#  'Australia': 726,
#  'shareholder': 727,
#  'compensation': 728,
#  'full': 729,
#  'drop': 730,
#  'damage': 731,
#  'supply': 732,
#  'buying': 733,
#  'slightly': 734,
#  'newspaper': 735,
#  'thought': 736,
#  'filed': 737,
#  '40': 738,
#  'estimated': 739,
#  '14': 740,
#  'research': 741,
#  'left': 742,
#  'announcement': 743,
#  'needs': 744,
#  'right': 745,
#  'local': 746,
#  'itself': 747,
#  'One': 748,
#  'fact': 749,
#  'health': 750,
#  'Meanwhile': 751,
#  'capital': 752,
#  'important': 753,
#  'rupees': 754,
#  'Fed': 755,
#  'boss': 756,
#  'weak': 757,
#  'settlement': 758,
#  'amid': 759,
#  'phone': 760,
#  'Asian': 761,
#  'drug': 762,
#  'find': 763,
#  'office': 764,
#  'makes': 765,
#  'pace': 766,
#  'Trade': 767,
#  'industrial': 768,
#  'owns': 769,
#  'operating': 770,
#  'debts': 771,
#  'raised': 772,
#  'positive': 773,
#  'continuing': 774,
#  'Airbus': 775,
#  'wants': 776,
#  'cutting': 777,
#  'April': 778,
#  '17': 779,
#  'David': 780,
#  'system': 781,
#  'weeks': 782,
#  'Under': 783,
#  'proposal': 784,
#  'problem': 785,
#  'Economic': 786,
#  'able': 787,
#  'times': 788,
#  'investigation': 789,
#  'guilty': 790,
#  'construction': 791,
#  'aircraft': 792,
#  'Argentina': 793,
#  'Oil': 794,
#  'service': 795,
#  'reduce': 796,
#  'risen': 797,
#  'speculation': 798,
#  'issue': 799,
#  'Brown': 800,
#  'place': 801,
#  'programme': 802,
#  'nearly': 803,
#  'allow': 804,
#  'points': 805,
#  'list': 806,
#  'provide': 807,
#  'directors': 808,
#  'John': 809,
#  'fiscal': 810,
#  'Parmalat': 811,
#  'access': 812,
#  'call': 813,
#  'rule': 814,
#  'merger': 815,
#  'Ukraine': 816,
#  'issues': 817,
#  'reforms': 818,
#  'projects': 819,
#  'similar': 820,
#  'short': 821,
#  'food': 822,
#  'Times': 823,
#  'policies': 824,
#  'General': 825,
#  'approval': 826,
#  'based': 827,
#  'known': 828,
#  'strength': 829,
#  'though': 830,
#  'difficult': 831,
#  'collapse': 832,
#  'Yuganskneftegas': 833,
#  'Baikal': 834,
#  'Manchester': 835,
#  'gains': 836,
#  'Rover': 837,
#  'extra': 838,
#  'again': 839,
#  'built': 840,
#  'final': 841,
#  'brands': 842,
#  'vehicles': 843,
#  'expect': 844,
#  'lead': 845,
#  'changes': 846,
#  'whose': 847,
#  'expansion': 848,
#  'might': 849,
#  '28': 850,
#  'driven': 851,
#  'majority': 852,
#  'asked': 853,
#  'building': 854,
#  'lot': 855,
#  'project': 856,
#  'Australian': 857,
#  'contract': 858,
#  'process': 859,
#  'build': 860,
#  'Barclays': 861,
#  'owner': 862,
#  'steel': 863,
#  'reserves': 864,
#  'fears': 865,
#  'continues': 866,
#  'risks': 867,
#  'travel': 868,
#  'effect': 869,
#  'real': 870,
#  'blamed': 871,
#  'outlook': 872,
#  'Paris': 873,
#  'terms': 874,
#  'created': 875,
#  'employment': 876,
#  'federal': 877,
#  'region': 878,
#  'disaster': 879,
#  'several': 880,
#  'investments': 881,
#  'With': 882,
#  'running': 883,
#  'North': 884,
#  'whole': 885,
#  'August': 886,
#  'effort': 887,
#  'failed': 888,
#  'Office': 889,
#  'area': 890,
#  'centre': 891,
#  'wine': 892,
#  'Italy': 893,
#  'listing': 894,
#  'ministers': 895,
#  'role': 896,
#  'scandal': 897,
#  'WTO': 898,
#  'open': 899,
#  'G7': 900,
#  'payments': 901,
#  'reform': 902,
#  '9bn': 903,
#  'card': 904,
#  'poverty': 905,
#  'family': 906,
#  'internet': 907,
#  'comment': 908,
#  'claimed': 909,
#  'showing': 910,
#  'small': 911,
#  'information': 912,
#  'position': 913,
#  'producer': 914,
#  'launch': 915,
#  'him': 916,
#  'denied': 917,
#  'quoted': 918,
#  'stores': 919,
#  'Lisbon': 920,
#  'rights': 921,
#  'Saudi': 922,
#  'plant': 923,
#  'subsidies': 924,
#  'factory': 925,
#  'Brazil': 926,
#  'planning': 927,
#  'rises': 928,
#  'retailers': 929,
#  'stronger': 930,
#  'division': 931,
#  '27': 932,
#  'efforts': 933,
#  'Reserve': 934,
#  'States': 935,
#  'developing': 936,
#  'rejected': 937,
#  'behind': 938,
#  'planned': 939,
#  'Many': 940,
#  'Airlines': 941,
#  'force': 942,
#  'technology': 943,
#  '13': 944,
#  'clear': 945,
#  'subsidiary': 946,
#  'July': 947,
#  'Congress': 948,
#  'These': 949,
#  'longer': 950,
#  'lawyers': 951,
#  'without': 952,
#  'network': 953,
#  'bill': 954,
#  'passengers': 955,
#  'gap': 956,
#  'ruling': 957,
#  'Cairn': 958,
#  'Sales': 959,
#  'Corp': 960,
#  'children': 961,
#  'Wall': 962,
#  'Swiss': 963,
#  'existing': 964,
#  'savings': 965,
#  'went': 966,
#  'limited': 967,
#  'Motors': 968,
#  'using': 969,
#  'massive': 970,
#  'Thailand': 971,
#  'range': 972,
#  'cards': 973,
#  '70': 974,
#  'brand': 975,
#  'signs': 976,
#  'remained': 977,
#  'believed': 978,
#  'tough': 979,
#  'Although': 980,
#  'situation': 981,
#  'ONS': 982,
#  'life': 983,
#  'recession': 984,
#  'tobacco': 985,
#  'reach': 986,
#  'improve': 987,
#  'Airways': 988,
#  'Nissan': 989,
#  'offered': 990,
#  'unlikely': 991,
#  'predicted': 992,
#  'tsunami': 993,
#  'spent': 994,
#  'us': 995,
#  'suffered': 996,
#  'Association': 997,
#  'launched': 998,
#  'overseas': 999,
#  'damages': 1000,
#  'available': 1001,
#  ...}

# %%
word2idx['<empty>'] = 0
word2idx['<eos>'] = 1

# %%
idx2word = dict((idx,word) for word,idx in word2idx.items())

# %%
import os
glove_path = r'./data/glove.6B/glove.6B.100d.txt'

# %%
glove_word_count = !wc -l {glove_path}

# %%
glove_word_count = int(glove_word_count[0].split(" ")[0])

# %%
glove_word_count
# Out:
# 400000

# %%
print(glove_word_count)
# Out:
# 400000

# %%
import numpy as np
glove_index_dict = {}
glove_embedding_weights = np.empty((glove_word_count, glove_vec_size))
with open(glove_path, 'r') as fp:
    i = 0
    for l in fp:
        l = l.strip().split() #split vector values
        word = l[0]
        glove_index_dict[word] = i
        slice = map(float,l[1:])
        glove_embedding_weights[i,:] = list(slice)
        i += 1

# %%
glove_embedding_weights
# Out:
# array([[-0.038194, -0.24487 ,  0.72812 , ..., -0.1459  ,  0.8278  ,
#          0.27062 ],
#        [-0.10767 ,  0.11053 ,  0.59812 , ..., -0.83155 ,  0.45293 ,
#          0.082577],
#        [-0.33979 ,  0.20941 ,  0.46348 , ..., -0.23394 ,  0.47298 ,
#         -0.028803],
#        ...,
#        [ 0.36088 , -0.16919 , -0.32704 , ...,  0.27139 , -0.29188 ,
#          0.16109 ],
#        [-0.10461 , -0.5047  , -0.49331 , ...,  0.42527 , -0.5125  ,
#         -0.17054 ],
#        [ 0.28365 , -0.6263  , -0.44351 , ...,  0.43678 , -0.82607 ,
#         -0.15701 ]])

# %%
for w,i in glove_index_dict.items():
    l = w.lower()
    if l not in glove_index_dict:
        glove_index_dict[l] = i

# %%
idx2word
# Out:
# {2: '.',
#  3: 'the',
#  4: ',',
#  5: 'to',
#  6: 'of',
#  7: 'in',
#  8: 'a',
#  9: 'and',
#  10: "'s",
#  11: '``',
#  12: 'The',
#  13: 'said',
#  14: 'is',
#  15: 'for',
#  16: 'that',
#  17: 'on',
#  18: '%',
#  19: 'has',
#  20: "''",
#  21: 'it',
#  22: 'by',
#  23: 'its',
#  24: 'was',
#  25: 'with',
#  26: 'as',
#  27: 'at',
#  28: '$',
#  29: 'be',
#  30: 'from',
#  31: 'have',
#  32: 'are',
#  33: 'US',
#  34: 'will',
#  35: '-',
#  36: 'year',
#  37: 'Mr',
#  38: 'which',
#  39: 'an',
#  40: '(',
#  41: ')',
#  42: 'had',
#  43: 'not',
#  44: 'would',
#  45: 'been',
#  46: 'than',
#  47: 'more',
#  48: 'also',
#  49: 'up',
#  50: 'were',
#  51: 'market',
#  52: 'company',
#  53: 'this',
#  54: 'their',
#  55: 'growth',
#  56: 'firm',
#  57: 'economy',
#  58: 'about',
#  59: 'he',
#  60: '1',
#  61: 'but',
#  62: 'government',
#  63: 'It',
#  64: 'new',
#  65: 'last',
#  66: 'could',
#  67: '2004',
#  68: 'after',
#  69: 'sales',
#  70: 'economic',
#  71: 'over',
#  72: 'In',
#  73: 'oil',
#  74: 'But',
#  75: 'they',
#  76: 'years',
#  77: '2',
#  78: 'prices',
#  79: "'",
#  80: 'chief',
#  81: 'China',
#  82: 'two',
#  83: 'may',
#  84: 'now',
#  85: 'one',
#  86: 'UK',
#  87: 'we',
#  88: 'deal',
#  89: 'shares',
#  90: 'rise',
#  91: 'business',
#  92: 'out',
#  93: '5',
#  94: 'Bank',
#  95: 'companies',
#  96: 'expected',
#  97: '3',
#  98: 'Yukos',
#  99: 'A',
#  100: 'world',
#  101: 'or',
#  102: 'who',
#  103: 'However',
#  104: 'into',
#  105: '2005',
#  106: '4',
#  107: 'firms',
#  108: 'his',
#  109: 'some',
#  110: 'dollar',
#  111: 'December',
#  112: 'country',
#  113: 'while',
#  114: 'months',
#  115: 'against',
#  116: 'other',
#  117: 'since',
#  118: 'people',
#  119: 'if',
#  120: 'still',
#  121: 'rate',
#  122: 'European',
#  123: 'time',
#  124: 'told',
#  125: 'there',
#  126: '2003',
#  127: 'first',
#  128: 'India',
#  129: 'We',
#  130: 'financial',
#  131: 'demand',
#  132: 'all',
#  133: 'quarter',
#  134: 'down',
#  135: 'made',
#  136: 'between',
#  137: 'countries',
#  138: 'rates',
#  139: 'interest',
#  140: 'such',
#  141: 'figures',
#  142: 'investment',
#  143: 'executive',
#  144: 'three',
#  145: 'biggest',
#  146: 'month',
#  147: 'any',
#  148: 'spending',
#  149: 'profits',
#  150: 'price',
#  151: 'many',
#  152: 'Europe',
#  153: 'state',
#  154: 'when',
#  155: 'added',
#  156: 'bank',
#  157: 'group',
#  158: '0',
#  159: 'jobs',
#  160: '8',
#  161: 'tax',
#  162: 'offer',
#  163: 'back',
#  164: '6',
#  165: 'euros',
#  166: 'strong',
#  167: 'rose',
#  168: 'bid',
#  169: 'much',
#  170: 'can',
#  171: 'trade',
#  172: 'costs',
#  173: 'set',
#  174: 'money',
#  175: 'stock',
#  176: 'no',
#  177: 'analysts',
#  178: 'I',
#  179: ';',
#  180: 'only',
#  181: 'most',
#  182: 'January',
#  183: 'foreign',
#  184: 'increase',
#  185: 'next',
#  186: 'should',
#  187: 'part',
#  188: 'cut',
#  189: '&',
#  190: 'fall',
#  191: 'share',
#  192: 'budget',
#  193: 'million',
#  194: 'hit',
#  195: 'make',
#  196: '10',
#  197: 'week',
#  198: 'our',
#  199: 'London',
#  200: 'recent',
#  201: 'He',
#  202: 'high',
#  203: 'Russian',
#  204: 'well',
#  205: 'Japan',
#  206: 'do',
#  207: 'move',
#  208: 'take',
#  209: 'Deutsche',
#  210: 'under',
#  211: 'industry',
#  212: 'says',
#  213: 'during',
#  214: 'being',
#  215: 'debt',
#  216: 'United',
#  217: 'likely',
#  218: 'pay',
#  219: 'report',
#  220: 'production',
#  221: '7',
#  222: 'fell',
#  223: 'This',
#  224: 'higher',
#  225: 'reported',
#  226: 'deficit',
#  227: 'former',
#  228: 'annual',
#  229: 'say',
#  230: 'Russia',
#  231: 'investors',
#  232: 'sale',
#  233: 'President',
#  234: 'because',
#  235: 'news',
#  236: 'court',
#  237: 'EU',
#  238: 'bankruptcy',
#  239: 'just',
#  240: 'number',
#  241: 'continue',
#  242: 'further',
#  243: 'off',
#  244: 'cost',
#  245: 'plans',
#  246: 'New',
#  247: '9',
#  248: 'record',
#  249: 'main',
#  250: 'November',
#  251: 'exports',
#  252: 'public',
#  253: 'seen',
#  254: 'case',
#  255: 'end',
#  256: 'giant',
#  257: 'future',
#  258: 'South',
#  259: 'profit',
#  260: 'unit',
#  261: 'markets',
#  262: 'less',
#  263: 'both',
#  264: 'Analysts',
#  265: 'largest',
#  266: 'boost',
#  267: ':',
#  268: 'too',
#  269: 'trading',
#  270: 'statement',
#  271: 'fraud',
#  272: 'euro',
#  273: 'consumer',
#  274: 'need',
#  275: 'sector',
#  276: 'car',
#  277: 'lost',
#  278: '5bn',
#  279: 'agreed',
#  280: 'German',
#  281: 'work',
#  282: 'meeting',
#  283: 'already',
#  284: 'GM',
#  285: 'before',
#  286: 'so',
#  287: 'put',
#  288: 'according',
#  289: 'shareholders',
#  290: "n't",
#  291: 'LSE',
#  292: 'stake',
#  293: 'low',
#  294: 'takeover',
#  295: 'buy',
#  296: 'global',
#  297: 'value',
#  298: 'decision',
#  299: 'earlier',
#  300: 'warned',
#  301: 'including',
#  302: 'came',
#  303: 'saying',
#  304: 'see',
#  305: 'club',
#  306: 'previous',
#  307: 'domestic',
#  308: 'help',
#  309: 'current',
#  310: 'through',
#  311: 'banks',
#  312: 'Tuesday',
#  313: 'Gazprom',
#  314: 'past',
#  315: 'airline',
#  316: 'October',
#  317: 'analyst',
#  318: 'them',
#  319: 'latest',
#  320: 'did',
#  321: 'get',
#  322: 'Fiat',
#  323: 'total',
#  324: 'talks',
#  325: 'good',
#  326: 'very',
#  327: 'announced',
#  328: '30',
#  329: 'board',
#  330: 'second',
#  331: 'earnings',
#  332: 'way',
#  333: 'economist',
#  334: 'key',
#  335: 'five',
#  336: 'There',
#  337: 'Bush',
#  338: 'period',
#  339: 'major',
#  340: 'sold',
#  341: 'products',
#  342: 'Boerse',
#  343: 'Indian',
#  344: 'own',
#  345: 'president',
#  346: 'top',
#  347: '20',
#  348: 'Friday',
#  349: 'Commission',
#  350: 'fuel',
#  351: 'level',
#  352: 'data',
#  353: 'Glazer',
#  354: 'Thursday',
#  355: 'Group',
#  356: 'where',
#  357: 'output',
#  358: 'ahead',
#  359: 'lower',
#  360: 'however',
#  361: 'September',
#  362: 'half',
#  363: 'recovery',
#  364: 'Ebbers',
#  365: 'reports',
#  366: 'exchange',
#  367: 'They',
#  368: 'agreement',
#  369: 'those',
#  370: 'what',
#  371: 'operations',
#  372: 'Asia',
#  373: 'assets',
#  374: 'York',
#  375: 'bought',
#  376: 'following',
#  377: 'Exchange',
#  378: 'On',
#  379: 'remain',
#  380: 'due',
#  381: 'going',
#  382: '12',
#  383: 'index',
#  384: 'impact',
#  385: 'charges',
#  386: 'director',
#  387: 'close',
#  388: 'Germany',
#  389: 'go',
#  390: 'despite',
#  391: 'far',
#  392: 'how',
#  393: 'even',
#  394: '15',
#  395: 'France',
#  396: 'increased',
#  397: 'gas',
#  398: 'inflation',
#  399: 'plan',
#  400: 'Reuters',
#  401: 'forecast',
#  402: 'Shares',
#  403: 'finance',
#  404: 'Yugansk',
#  405: 'ВЈ1',
#  406: 'come',
#  407: 'support',
#  408: 'early',
#  409: 'face',
#  410: 'Japanese',
#  411: 'cash',
#  412: 'development',
#  413: '1bn',
#  414: 'control',
#  415: 'World',
#  416: 'legal',
#  417: 'result',
#  418: 'Rosneft',
#  419: 'law',
#  420: 'these',
#  421: 'same',
#  422: 'currently',
#  423: 'businesses',
#  424: 'spokesman',
#  425: 'action',
#  426: 'IMF',
#  427: 'four',
#  428: 'manufacturing',
#  429: 'currency',
#  430: '3bn',
#  431: 'workers',
#  432: 'believe',
#  433: 'Monday',
#  434: 'Wednesday',
#  435: 'corporate',
#  436: 'rising',
#  437: 'America',
#  438: 'accounts',
#  439: 'big',
#  440: 'private',
#  441: 'does',
#  442: '4bn',
#  443: 'job',
#  444: 'house',
#  445: '11',
#  446: 'chairman',
#  447: 'making',
#  448: 'below',
#  449: 'As',
#  450: 'whether',
#  451: 'until',
#  452: 'insurance',
#  453: 'credit',
#  454: 'cuts',
#  455: 'third',
#  456: 'unemployment',
#  457: 'leading',
#  458: 'found',
#  459: '2002',
#  460: 'retail',
#  461: 'few',
#  462: 'MCI',
#  463: 'remains',
#  464: 'around',
#  465: 'customers',
#  466: 'almost',
#  467: 'And',
#  468: '2001',
#  469: 'minister',
#  470: 'long',
#  471: 'Chinese',
#  472: 'BBC',
#  473: 'then',
#  474: 'day',
#  475: 'average',
#  476: 'policy',
#  477: 'property',
#  478: 'order',
#  479: 'revenues',
#  480: 'account',
#  481: 'agency',
#  482: 'At',
#  483: 'use',
#  484: 'levels',
#  485: 'executives',
#  486: 'rules',
#  487: 'aid',
#  488: 'SEC',
#  489: 'better',
#  490: 'energy',
#  491: 'auction',
#  492: '25',
#  493: 'growing',
#  494: 'results',
#  495: 'saw',
#  496: 'think',
#  497: 'start',
#  498: 'possible',
#  499: 'ago',
#  500: 'meet',
#  501: 'rival',
#  502: 'staff',
#  503: '8bn',
#  504: 'forced',
#  505: 'performance',
#  506: 'If',
#  507: 'protection',
#  508: 'political',
#  509: 'According',
#  510: 'large',
#  511: 'best',
#  512: 'although',
#  513: 'survey',
#  514: 'problems',
#  515: 'Boeing',
#  516: '6bn',
#  517: 'housing',
#  518: 'Securities',
#  519: 'taking',
#  520: 'international',
#  521: 'compared',
#  522: 'Financial',
#  523: 'Last',
#  524: 'like',
#  525: 'led',
#  526: 'give',
#  527: 'Iraq',
#  528: 'competition',
#  529: 'Minister',
#  530: 'services',
#  531: 'taken',
#  532: 'officials',
#  533: 'took',
#  534: 'product',
#  535: 'least',
#  536: '2006',
#  537: 'look',
#  538: 'across',
#  539: 'French',
#  540: 'change',
#  541: '2bn',
#  542: 'News',
#  543: 'Christmas',
#  544: 'fourth',
#  545: 'among',
#  546: 'International',
#  547: 'Ms',
#  548: 'authorities',
#  549: 'another',
#  550: 'claims',
#  551: 'Its',
#  552: 'target',
#  553: 'given',
#  554: 'become',
#  555: 'used',
#  556: 'figure',
#  557: 'claim',
#  558: 'banking',
#  559: 'above',
#  560: 'WorldCom',
#  561: 'hold',
#  562: '50',
#  563: 'trillion',
#  564: 'needed',
#  565: 'February',
#  566: 'enough',
#  567: 'showed',
#  568: 'England',
#  569: 'crude',
#  570: 'confidence',
#  571: 'Sri',
#  572: 'Stock',
#  573: 'maker',
#  574: 'helped',
#  575: 'keep',
#  576: 'yet',
#  577: 'having',
#  578: 'nations',
#  579: 'raise',
#  580: 'Union',
#  581: 'later',
#  582: 'recently',
#  583: 'senior',
#  584: 'general',
#  585: 'accounting',
#  586: 'mortgage',
#  587: 'Air',
#  588: 'sell',
#  589: 'fund',
#  590: 'decline',
#  591: 'GDP',
#  592: 'previously',
#  593: 'include',
#  594: 'creditors',
#  595: 'British',
#  596: 'March',
#  597: 'rather',
#  598: 'days',
#  599: 'create',
#  600: 'significant',
#  601: 'loss',
#  602: 'consumers',
#  603: 'risk',
#  604: 'accused',
#  605: 'Khodorkovsky',
#  606: 'Standard',
#  607: 'slowdown',
#  608: 'Turkey',
#  609: 'run',
#  610: 'losses',
#  611: 'point',
#  612: 'closed',
#  613: 'That',
#  614: 'called',
#  615: 'pressure',
#  616: 'taxes',
#  617: 'American',
#  618: 'term',
#  619: 'concerns',
#  620: 'head',
#  621: 'hopes',
#  622: 'held',
#  623: 'looking',
#  624: 'focus',
#  625: 'Some',
#  626: 'comes',
#  627: 'worth',
#  628: 'areas',
#  629: 'trying',
#  630: 'affected',
#  631: 'telecoms',
#  632: 'cars',
#  633: 'poor',
#  634: 'show',
#  635: 'Korea',
#  636: 'Euronext',
#  637: 'conditions',
#  638: 'yen',
#  639: 'Sunday',
#  640: 'huge',
#  641: '100',
#  642: 'little',
#  643: 'mobile',
#  644: 'Marsh',
#  645: 'members',
#  646: 'Lanka',
#  647: 'you',
#  648: 'airlines',
#  649: 'For',
#  650: 'grew',
#  651: 'revenue',
#  652: 'administration',
#  653: 'means',
#  654: 'National',
#  655: 'official',
#  656: 'want',
#  657: 'within',
#  658: 'home',
#  659: 'Street',
#  660: 'six',
#  661: 'net',
#  662: 'management',
#  663: 'paid',
#  664: 'national',
#  665: 'Despite',
#  666: '16',
#  667: 'income',
#  668: 'BMW',
#  669: 'grow',
#  670: 'evidence',
#  671: 'Africa',
#  672: 'facing',
#  673: 'amount',
#  674: 'reached',
#  675: '7bn',
#  676: 'goods',
#  677: 'Department',
#  678: 'signed',
#  679: 'coming',
#  680: 'benefits',
#  681: '18',
#  682: 'working',
#  683: 'selling',
#  684: 'overall',
#  685: 'dropped',
#  686: 'proposals',
#  687: 'slow',
#  688: 'lending',
#  689: 'power',
#  690: 'trial',
#  691: 'once',
#  692: 'Indonesia',
#  693: '2000',
#  694: 'expectations',
#  695: 'highest',
#  696: 'Federal',
#  697: 'late',
#  698: 'fallen',
#  699: 'per',
#  700: 'must',
#  701: 'falling',
#  702: 'officer',
#  703: 'line',
#  704: 'potential',
#  705: 'loans',
#  706: 'Sullivan',
#  707: 'central',
#  708: 'May',
#  709: 'election',
#  710: 'turn',
#  711: 'funds',
#  712: 'forecasts',
#  713: 'leaders',
#  714: 'expects',
#  715: 'dollars',
#  716: 'each',
#  717: 'adding',
#  718: 'activity',
#  719: 'she',
#  720: 'Italian',
#  721: 'continued',
#  722: 'economists',
#  723: 'While',
#  724: 'return',
#  725: 'S',
#  726: 'Australia',
#  727: 'shareholder',
#  728: 'compensation',
#  729: 'full',
#  730: 'drop',
#  731: 'damage',
#  732: 'supply',
#  733: 'buying',
#  734: 'slightly',
#  735: 'newspaper',
#  736: 'thought',
#  737: 'filed',
#  738: '40',
#  739: 'estimated',
#  740: '14',
#  741: 'research',
#  742: 'left',
#  743: 'announcement',
#  744: 'needs',
#  745: 'right',
#  746: 'local',
#  747: 'itself',
#  748: 'One',
#  749: 'fact',
#  750: 'health',
#  751: 'Meanwhile',
#  752: 'capital',
#  753: 'important',
#  754: 'rupees',
#  755: 'Fed',
#  756: 'boss',
#  757: 'weak',
#  758: 'settlement',
#  759: 'amid',
#  760: 'phone',
#  761: 'Asian',
#  762: 'drug',
#  763: 'find',
#  764: 'office',
#  765: 'makes',
#  766: 'pace',
#  767: 'Trade',
#  768: 'industrial',
#  769: 'owns',
#  770: 'operating',
#  771: 'debts',
#  772: 'raised',
#  773: 'positive',
#  774: 'continuing',
#  775: 'Airbus',
#  776: 'wants',
#  777: 'cutting',
#  778: 'April',
#  779: '17',
#  780: 'David',
#  781: 'system',
#  782: 'weeks',
#  783: 'Under',
#  784: 'proposal',
#  785: 'problem',
#  786: 'Economic',
#  787: 'able',
#  788: 'times',
#  789: 'investigation',
#  790: 'guilty',
#  791: 'construction',
#  792: 'aircraft',
#  793: 'Argentina',
#  794: 'Oil',
#  795: 'service',
#  796: 'reduce',
#  797: 'risen',
#  798: 'speculation',
#  799: 'issue',
#  800: 'Brown',
#  801: 'place',
#  802: 'programme',
#  803: 'nearly',
#  804: 'allow',
#  805: 'points',
#  806: 'list',
#  807: 'provide',
#  808: 'directors',
#  809: 'John',
#  810: 'fiscal',
#  811: 'Parmalat',
#  812: 'access',
#  813: 'call',
#  814: 'rule',
#  815: 'merger',
#  816: 'Ukraine',
#  817: 'issues',
#  818: 'reforms',
#  819: 'projects',
#  820: 'similar',
#  821: 'short',
#  822: 'food',
#  823: 'Times',
#  824: 'policies',
#  825: 'General',
#  826: 'approval',
#  827: 'based',
#  828: 'known',
#  829: 'strength',
#  830: 'though',
#  831: 'difficult',
#  832: 'collapse',
#  833: 'Yuganskneftegas',
#  834: 'Baikal',
#  835: 'Manchester',
#  836: 'gains',
#  837: 'Rover',
#  838: 'extra',
#  839: 'again',
#  840: 'built',
#  841: 'final',
#  842: 'brands',
#  843: 'vehicles',
#  844: 'expect',
#  845: 'lead',
#  846: 'changes',
#  847: 'whose',
#  848: 'expansion',
#  849: 'might',
#  850: '28',
#  851: 'driven',
#  852: 'majority',
#  853: 'asked',
#  854: 'building',
#  855: 'lot',
#  856: 'project',
#  857: 'Australian',
#  858: 'contract',
#  859: 'process',
#  860: 'build',
#  861: 'Barclays',
#  862: 'owner',
#  863: 'steel',
#  864: 'reserves',
#  865: 'fears',
#  866: 'continues',
#  867: 'risks',
#  868: 'travel',
#  869: 'effect',
#  870: 'real',
#  871: 'blamed',
#  872: 'outlook',
#  873: 'Paris',
#  874: 'terms',
#  875: 'created',
#  876: 'employment',
#  877: 'federal',
#  878: 'region',
#  879: 'disaster',
#  880: 'several',
#  881: 'investments',
#  882: 'With',
#  883: 'running',
#  884: 'North',
#  885: 'whole',
#  886: 'August',
#  887: 'effort',
#  888: 'failed',
#  889: 'Office',
#  890: 'area',
#  891: 'centre',
#  892: 'wine',
#  893: 'Italy',
#  894: 'listing',
#  895: 'ministers',
#  896: 'role',
#  897: 'scandal',
#  898: 'WTO',
#  899: 'open',
#  900: 'G7',
#  901: 'payments',
#  902: 'reform',
#  903: '9bn',
#  904: 'card',
#  905: 'poverty',
#  906: 'family',
#  907: 'internet',
#  908: 'comment',
#  909: 'claimed',
#  910: 'showing',
#  911: 'small',
#  912: 'information',
#  913: 'position',
#  914: 'producer',
#  915: 'launch',
#  916: 'him',
#  917: 'denied',
#  918: 'quoted',
#  919: 'stores',
#  920: 'Lisbon',
#  921: 'rights',
#  922: 'Saudi',
#  923: 'plant',
#  924: 'subsidies',
#  925: 'factory',
#  926: 'Brazil',
#  927: 'planning',
#  928: 'rises',
#  929: 'retailers',
#  930: 'stronger',
#  931: 'division',
#  932: '27',
#  933: 'efforts',
#  934: 'Reserve',
#  935: 'States',
#  936: 'developing',
#  937: 'rejected',
#  938: 'behind',
#  939: 'planned',
#  940: 'Many',
#  941: 'Airlines',
#  942: 'force',
#  943: 'technology',
#  944: '13',
#  945: 'clear',
#  946: 'subsidiary',
#  947: 'July',
#  948: 'Congress',
#  949: 'These',
#  950: 'longer',
#  951: 'lawyers',
#  952: 'without',
#  953: 'network',
#  954: 'bill',
#  955: 'passengers',
#  956: 'gap',
#  957: 'ruling',
#  958: 'Cairn',
#  959: 'Sales',
#  960: 'Corp',
#  961: 'children',
#  962: 'Wall',
#  963: 'Swiss',
#  964: 'existing',
#  965: 'savings',
#  966: 'went',
#  967: 'limited',
#  968: 'Motors',
#  969: 'using',
#  970: 'massive',
#  971: 'Thailand',
#  972: 'range',
#  973: 'cards',
#  974: '70',
#  975: 'brand',
#  976: 'signs',
#  977: 'remained',
#  978: 'believed',
#  979: 'tough',
#  980: 'Although',
#  981: 'situation',
#  982: 'ONS',
#  983: 'life',
#  984: 'recession',
#  985: 'tobacco',
#  986: 'reach',
#  987: 'improve',
#  988: 'Airways',
#  989: 'Nissan',
#  990: 'offered',
#  991: 'unlikely',
#  992: 'predicted',
#  993: 'tsunami',
#  994: 'spent',
#  995: 'us',
#  996: 'suffered',
#  997: 'Association',
#  998: 'launched',
#  999: 'overseas',
#  1000: 'damages',
#  1001: 'available',
#  ...}

# %%
np.random.seed(42)
shape = (glove_word_count, glove_vec_size)
scale = glove_embedding_weights.std()
embedding = np.random.uniform(low=-scale, high=scale, size=shape)

c = 0
for i in range(len(vocabcount)):
    word = idx2word[i]
    glove_idx = glove_index_dict.get(word) or glove_index_dict.get(word.lower())
    if glove_idx is not None:
        embedding[i,:] = glove_embedding_weights[glove_idx,:]
        c+=1
    else:
        print(word)
c
# Out:
# <empty>
# <eos>
# 5bn
# ВЈ1
# 4bn
# 8bn
# 6bn
# 7bn
# 9bn
# ВЈ2
# ВЈ3
# 11bn
# ВЈ4
# ВЈ5
# 27bn
# 20bn
# 16bn
# Phytopharm
# ВЈ800m
# ВЈ7
# 75bn
# 300p
# 280bn
# ВЈ10
# 35bn
# ВЈ8
# 180bn
# Krivorizhstal
# ODPM
# Apacs
# ВЈ6
# ВЈ1bn
# rate-setting
# 45bn
# with-profits
# 'to
# 25bn
# Diemont
# Agroflora
# ВЈ9
# 850m
# like-for-like
# 19bn
# 30bn
# Easymobile
# ВЈ200m
# Toshitsune
# Contrack
# Illva
# back-tax
# 13bn
# anti-racketeering
# 12bn
# ВЈ21
# 96bn
# 17bn
# 14bn
# 375m
# 200bn
# 23bn
# business-based
# ВЈ10bn
# Paulsmeier
# post-Christmas
# 37bn
# ex-Yukos
# Mohd-Saaid
# 'may
# ex-boss
# 28bn
# sell-offs
# ВЈ42m
# ВЈ194m
# 168m
# 206bn
# US-German
# ERAA
# 136m
# ВЈ14
# ВЈ350m
# 412bn
# ВЈ100m
# 89bn
# car-making
# 68m
# renationalise
# 91m
# Irancell
# 427bn
# October-to-December
# ВЈ1m
# ВЈ424m
# 80bn
# 100bn
# Jinshajiang
# buy-to-let
# ВЈ6bn
# technology-dominated
# ВЈ5bn
# Prettejohn
# ВЈ100
# split-capital
# ВЈ52m
# 15bn
# AEFA
# ВЈ14bn
# 60bn
# 'put
# Cochilco
# Fiat-GM
# 515m
# 'strong
# post-Enron
# post-quake
# 54m
# 368bn
# year-earlier
# 36bn
# worse-than-expected
# ВЈ75m
# ВЈ160m
# 97bn
# Egelton
# ВЈ155bn
# ВЈ170m
# Frank-Juergen
# seasonally-adjusted
# 32bn
# ВЈ16
# Charcote
# larger-than-expected
# 04bn
# better-than-expected
# ВЈ15
# ВЈ24
# baby-boom
# gigajoule
# re-listing
# 05bn
# ВЈ198m
# ВЈ190m
# Bewlay
# ВЈ415m
# beer-flavoured
# 950m
# pre-payment
# Lukashov
# 160bn
# ВЈ53
# 41bn
# ВЈ230bn
# bid-rigging
# 984m
# 99bn
# German-US
# ex-Columbia
# 47bn
# Otoku
# ВЈ38
# 33bn
# Gibraltar-based
# 630m
# politically-motivated
# Inoni
# 87bn
# 55bn
# Lilliu
# ВЈ400m
# ВЈ13bn
# Frankfurt-based
# 48bn
# 'wait
# anti-Aids
# Itrec
# Addink
# former-President
# Aishwariya
# 65bn
# Haji-Ioannou
# with-profit
# With-profits
# ВЈ138m
# Hemington
# 300-shareholder
# capitalisations
# ВЈ374m
# 07bn
# ВЈ558m
# 331bn
# 39m
# ВЈ21m
# 75p
# desmoteplase
# 'chip
# card-not-present
# Sudell
# ВЈ26
# ВЈ36
# ex-finance
# Monica-based
# Activison
# X-Box
# slower-than-expected
# trade-driven
# 18bn
# nano-technology
# worst-affected
# tsunami-affected
# ВЈ398m
# 768m
# Chaiyasoot
# 660m
# London-Frankfurt
# shake-out
# nose-diving
# ВЈ1,200
# Singapore-listed
# 54bn
# significantly-improved
# 440,700
# 22bn
# market-set
# widely-predicted
# over-abrupt
# ВЈ19
# Khurmala
# Himrin
# Alcobev
# ВЈ3bn
# ВЈ25
# Shipside
# ВЈ600
# ВЈ190,329
# ВЈ189,733
# 377bn
# ВЈ26m
# Gorur
# export-driven
# Troeber
# 38am
# ВЈ28
# Alfa-Eco
# Boix-Vives
# Management-Chicago
# year-ago
# Douglas-Westwood
# tsunami-hit
# ВЈ82
# Macaefa
# 648m
# Atomstroieksport
# 0-
# 66m
# 98m
# euros-worth
# Corcostegui
# Rubinsohn
# 'lose
# 'set
# 'hits
# 'more
# 'stronger
# Turkey-Iran
# 'at
# 'slowing
# 'left
# 'Strong
# 'cuts
# 'intact
# ex-aide
# Ex-Boeing
# 'seals
# 'hit
# 'make
# 'loses
# 'not
# 'Post-Christmas
# 'risks
# 'illegal
# 'Standoff
# 'toughest
# 'delayed
# 'genius
# 'fail
# long-living
# 'targeting
# 'ticking
# 'aware
# 'great
# Split-caps
# post-takeover
# 'defies
# 'too
# 'excellent
# 'major
# 'should
# 'poised
# 'controlled
# 'tough
# 'less
# feud-hit
# 100m-share
# 'idle
# 'woo
# 'bids
# 'sets
# EU-US
# 'in
# 'Golden
# 'state
# 'declines
# colludes
# ВЈ600m
# 639m
# search-engine
# 284m
# 09bn
# 2871
# 2974
# ВЈ479m
# 540m
# 141m
# ВЈ125m
# ВЈ106m
# ВЈ59m
# ВЈ250m
# patchier
# 387,500
# 86m
# ВЈ46m
# 204m
# 187m
# 58bn
# badly-needed
# 540bn
# 77bn
# newly-appointed
# 472bn
# ВЈ150m
# ВЈ173
# ELAA
# 'bumping
# EU-based
# pay-out
# Quillinan-Meiland
# tooling-up
# overbalancing
# 77m
# ВЈ53m
# 4bn-euro
# 'BB+
# 'BBB-
# 'always
# 'on
# Sunovate
# ВЈ300m
# ВЈ392
# one-euro
# Kronawitter
# ВЈ484bn
# 162bn
# ВЈ56
# previously-unknown
# 155,465
# Silverade
# 19,924
# 17,815
# Raniers
# non-Opec
# latifundios
# not-too-distant
# 6661
# 'miracle
# 29bn
# UFJ-MTFG
# technology-sharing
# ВЈ546m
# ВЈ532m
# share-ownership
# ВЈ960m
# 85bn
# 364m
# ВЈ30
# soon-to-retire
# ВЈ51
# al-Gosaibi
# highly-educated
# 4850
# -which
# -may
# Ryanair/Boeing
# 34bn
# rapidly-rising
# ВЈ280m
# Wernle
# ВЈ10,000
# ВЈ11,500
# ВЈ17,730
# ВЈ15,690
# ВЈ8,000
# ВЈ12,556
# the-car
# C180
# 116i
# Mini-workers
# ВЈ39
# 861m
# ВЈ451m
# Brabeck-Letmathe
# 53bn
# -best
# 775m
# wholly-
# brain-drain
# small-
# 24bn
# ВЈ130m
# ВЈ234m
# ВЈ220m
# ВЈ610m
# ВЈ105m
# ВЈ80m
# Mong-koo
# ВЈ910m
# 418bn-rand
# BMW-brand
# 80,600
# Rolls-Royces
# ВЈ265m
# ex-head
# Ebber
# 813,200
# ВЈ458m
# 874m
# writeback
# medium-distance
# Schulte-Strathaus
# Weidensteiner
# least-developed
# 300bn
# ВЈ158
# Vancheshwar
# 'automatic
# Chittabrata
# twin-aisle
# rolled-out
# 186m
# ВЈ98m
# 143m
# public-company
# itselfBeer
# beer-like
# Shinnama
# non-beer
# 291m
# ВЈ154m
# third-type
# month-on-month
# Atinc
# Turkish-Austrian
# investment-friendly
# Oganesyan
# 06bn
# capital-raising
# Juchemich
# 635,173
# 546m
# ВЈ290m
# 246,570
# near-400,000
# home-shopping
# food-for-oil
# 'Television
# DHL-owner
# 873p
# Bracknell-based
# ВЈ328m
# 950p
# 82bn
# Komileva
# 901m
# higher-return
# 0619
# 'New
# 119bn
# 113bn
# outweight
# Dogusoy
# part-Turkish
# 51bn
# smaller-than-expected
# January-to-March
# ВЈ486,000
# 705m
# 966m
# ВЈ13
# 2944
# 3006
# four-nation
# 166bn
# seventy-year
# gas-guzzling
# petrol-price
# well-flagged
# anti-bribery
# bigger-than-expected
# 676m
# ВЈ352m
# ВЈ195
# price-rigging
# 618m
# 232m
# 337m
# 360m
# upper-teens
# ВЈ149bn
# ВЈ80,000
# 61m
# ВЈ274
# 73m
# 380m
# dual-ownership
# Sweere
# ВЈ12
# 578m
# 72bn
# PagesJaunes
# '771
# 1,000bn
# ВЈ537bn
# Cross-selling
# NikkoCitigroup
# 785m
# 784m
# 374m
# mini-car
# 506m
# 142bn
# 475m
# DaimerChrysler
# ВЈ722m
# Carl-Henric
# all-communicating
# widely-expected
# 154m
# ВЈ591,000
# 2bn-worth
# tech-production
# 10,385
# ВЈ277m
# ex-senior
# market-timing
# BACAP
# Tambone
# ex-managers
# 50-100,000
# Metrovias
# fast-rising
# ВЈ550m
# 246bn
# ВЈ347m
# ВЈ801m
# ВЈ191m
# 431m
# 245m
# ITPC
# road-show
# ВЈ18
# Rosneft-owned
# London-listed
# Gazprom-Rosneft
# 719m
# re-merchandising
# rock-bottom
# Bridgewell
# stubbornly-high
# Hartz-IV
# Democrat-Green
# internationally-accepted
# ILO-based
# Arcleor
# much-higher
# Sheffield-based
# car-style
# van-style
# mini-van
# Accura
# 3218
# 9094
# 850bn
# ВЈ933m
# 78bn
# Shihab-Eldin
# ВЈ980m
# faming
# fully-operational
# Carl-Peter
# desperately-needed
# ВЈ104m
# 151m
# Vauxhalls
# Tysabri-treated
# re-initiation
# ВЈ152,879
# 1998/9
# vote-catching
# 11,740
# UK-Dutch
# Qatargas-2
# Qatargas-4
# 830bn
# 56bn
# industryIn
# ВЈ131,961
# stategist
# ВЈ11bn
# quarter-point
# cross-London
# ВЈ180,126
# ВЈ178,906
# ВЈ83
# 88bn
# ВЈ0
# 537m
# 701m
# ВЈ371m
# 798m
# 26bn
# 456m
# medium-to-long
# hydroelectric-power
# 365m
# re-selling
# ВЈ280
# 532m
# ВЈ450
# 3187
# Mohi-Uddin
# rock-steady
# 'loan-for-oil
# non-wage
# Beck-Crespel
# Boscholt
# Stueker
# DrKW
# -and
# 1,050-1,125
# 24-
# ex-travel
# 443m
# ВЈ230
# Claquin
# ВЈ581m
# Vioxx-related
# Mihkail
# Westfallen
# 89m
# ВЈ47m
# Peter-Thilo
# Halser
# ВЈ17
# ВЈ2bn
# ВЈ4bn
# record-busting
# Perchesk
# 1130p
# 'tax
# -thought
# -are
# Barrioneuvo
# Kuhlhoff
# belt-tightening
# 230bn
# 587m
# re-orders
# Matshushita
# intellect-enhancing
# 'le
# 684bn
# Moscow-backed
# Veron-Reville
# 'pragmatic
# interest-payment
# Molsiris
# ВЈ266m
# UK-listed
# 548p
# Russian-owned
# Russian-registered
# 339m
# ВЈ182
# ВЈ308m
# 797p
# ВЈ40m-ВЈ50m
# big-ticket
# pay-day
# jelly-legged
# ВЈ135m
# SLBA
# ВЈ49m
# Paion
# Tsusaka
# lower-skilled
# 'card-not-present
# card-present
# UK-issued
# ВЈ402
# Card-not-present
# ВЈ116
# ВЈ43m
# ВЈ52
# PIBS
# ВЈ370m
# ВЈ163,748
# 38bn
# 50bn
# 69bn
# water-and-weather-tight
# well-insulated
# uplights
# downlights
# dimmable
# router/access
# ВЈ35
# ВЈ32
# Interest-sensitive
# ill-serve
# detail-oriented
# July-to-September
# ВЈ182,920
# ВЈ187,971
# July-September
# 36,185
# 28,041
# million-pound
# pro-growth
# 327m
# ВЈ22m
# 31bn
# mis-steps
# direct-sales
# highly-regulated
# Panayis
# Freedom2surf
# IPStream
# 95bn
# 57bn
# dizzyingly-high
# one-lira
# Serdengecti
# slimmed-down
# Hayriye
# ВЈ227bn
# Confifi
# Delaware*
# unguessable
# trillion-dollar
# Reisurance
# Goetti
# Mediterranne
# Floiran
# Woest
# 10,847
# analsyts
# report*
# clearly-defined
# ВЈ250
# ВЈ500
# instant-access
# FirstSaver
# ВЈ4,745
# R85
# non-taxpayer
# ВЈ514m
# red-tape
# ВЈ690m
# early-winter
# Ofex
# money-earning
# 24,997
# Paschoal
# 500bn
# 800bn
# closely-watched
# 572,900
# Jasperneite
# million-2
# energy-starved
# 21bn
# over-egged
# Rhiel
# ВЈ50
# ВЈ46,998
# ВЈ12,700
# 11,488
# Aberdeen-based
# Baghdad-based
# geo-scientists
# 101-year-old
# Torao
# re-devise
# 86bn
# Roukis
# 'Ray
# 5,196
# debt-laden
# 10,137
# tax-cutting
# 422bn
# 10,227
# non-manufacturers
# Multi-Fibre
# 'race
# 790m
# Geijsen
# questionsmarks
# Yuganskneftgas
# Gadaravice
# ВЈ309m
# 725m
# plane-making
# 133m
# N-C
# production-sharing
# 247p
# ВЈ686m
# Anglo-Swedish
# anti-coagulant
# AztraZeneca
# ВЈ135
# 42bn
# made-made
# 105bn
# ВЈ54bn
# scandal-hit
# 97p
# 44p
# ВЈ258
# Everasia
# IOG
# Suba-Luhais
# state-backed
# Kiknavelidze
# 66bn
# 106m
# ВЈ54
# non-convertible
# pence-a-share
# 583p
# 533p
# al-Jibouri
# 260m
# ВЈ134m
# ВЈ4m
# ВЈ25bn
# 98bn
# ВЈ6,500
# 261bn
# fourth-biggest
# Yuganksneftegas
# cannabis-based
# Satifex
# non-defence
# ВЈ211
# Scathes
# AARA
# Reveta
# ВЈ30,800
# state-ownership
# cloak-and-dagger
# Sovlink
# renationalising
# 325m
# Schnaible
# agreed-to
# super-economical
# 200-
# ВЈ55,000
# ВЈ568m
# Junhuai
# 417m
# ВЈ931m
# quick-growing
# ВЈ146m
# 281m
# ВЈ230m
# 47m
# 177,600
# ВЈ140bn
# 258bn
# 560m
# ВЈ291m
# 3516
# 3509
# euro/dollar
# 510m
# ВЈ70m
# tsunami-related
# ВЈ281m
# 640m
# Bermuda-based
# April-July
# ВЈ97m
# April-September
# airlines-
# flight-crew
# court-imposed
# congressionally-mandated
# ex-parent
# Ji-chang
# Yungmin
# Nanik
# Rupani
# Bombay-based
# faster-than-expected
# ВЈ425,000
# Foundation-Kazakhstan
# Abish-uly
# Khordokovsky
# ВЈ269bn
# ВЈ268bn
# US-registered
# 912km
# ВЈ173m
# condom-maker
# Syndol
# Meltus
# value-creating
# ВЈ20
# ВЈ42
# ВЈ23bn
# ВЈ12m
# ВЈ183
# Staropramen
# Leuven-based
# Novocheboksarsk
# ski-maker
# 3652
# 3667
# 960m
# ВЈ499m
# 480m
# Laah
# Chong-gyu
# 3666
# 3636
# co-sign
# Naftohaz
# -owned
# Chada
# 8832
# ВЈ5m
# ВЈ425m
# 779m-798m
# Like-for-like
# ВЈ420m
# FT-30
# ВЈ2m
# Ivankoe
# onstart
# 206,900
# non-seasonally
# communist-style
# pro-Chavez
# Mohieldin
# 74m
# Mitroshin
# pence-per-share
# Ainum
# Navarednam
# Metrojaya
# ВЈ118m
# 376m
# 200p
# ВЈ530m
# 94m
# SimpliFares
# ВЈ264
# Saturday-night
# 646m
# ВЈ24bn
# SalterBaxter
# Lee-Harwood
# pro-sustainability
# ВЈ691m
# 320m
# ВЈ27m
# ВЈ799,000
# genetically-modified
# chemicals-and-crops
# Jakarta-based
# Areen
# ВЈ162,086
# 220bn
# larger-than-forecast
# Neilsen/Net
# 49m
# 449,603
# 44bn
# 925p
# Asia-wide
# 20-30bn
# ВЈ93
# ВЈ89m
# 155m
# ВЈ378
# 2001alleging
# 145m
# ВЈ180,226
# ВЈ180,444
# ВЈ192,713
# ВЈ139,544
# ВЈ116,542
# ВЈ111,314
# ВЈ262,825
# ВЈ96bn
# haute-couture
# Privately-held
# ВЈ522,000
# over-stated
# 40bn
# ВЈ21bn
# Jufeyr
# Sydney-
# freight-carrying
# triple-decker
# 434m
# ВЈ231m
# 732m
# Iliaronov
# 311bn
# ВЈ165bn
# 420bn
# Congressionally-mandated
# 124bn
# 150bn
# 6709
# anti-Musharraf
# shownThe
# ВЈ29bn
# clean-burning
# normal-engined
# Trouble-hit
# evalution
# 717m
# ВЈ379m
# Thadao
# Reline
# Oatleys
# 846m
# Lensworth
# back-flip
# cigarette-making
# Wangli
# STMC
# 210bn
# Schilbe
# ВЈ31
# 3280
# 1,8923
# ВЈ27
# trade-in-services
# Mafeca
# calorie-heavy
# re-positioning
# ВЈ428m
# 'urban
# ВЈ265
# non-store
# 17-a-share
# 'opening
# 584m
# straight-talking
# inflation-fighting
# 492m
# willmean
# 'offshore
# Mijatov
# back-taxes
# ВЈ110m
# 142m
# 387m
# ВЈ206m
# 111m
# 56m
# 761m
# ВЈ481
# 345m
# 569m
# 838m
# 193bn
# 495m
# ВЈ275m
# 330m
# ВЈ750m
# pre-tsunami
# Xiluodi
# 'river
# UK-published
# Nigerian-owned
# Sydney-listed
# Jean-Rene
# ВЈ690,000
# publicly-listed
# Israeli-Egyptian
# 104m
# 793m
# 470m
# ВЈ13m
# full-hybrid
# LR3/Discovery
# 6,798,000
# 1,751,000
# 697m
# 153m
# ASK-Raymond
# non-seasonally-adjusted
# Jessops
# low-prevalence
# 253m
# ВЈ175m
# 328m
# ВЈ775
# ВЈ429m
# 138p
# Leicestershire-based
# ready-mixed
# 745bn
# Dhiru
# ritzier
# ВЈ197bn
# 348bn
# 855bn
# 2-
# Iraq-related
# ВЈ179
# Janeir
# previously-pledged
# 'normal
# Italaudit
# 22,953
# 'I
# ВЈ64m
# China-published
# 190bn
# loans-for-favours
# Scandal-hit
# 220m
# ВЈ117m
# late-November
# 789m
# 03bn
# ВЈ548m
# vehicle-carrying
# ВЈ72
# water-concession
# 242m
# Maghnia
# 39bn
# ВЈ29
# 069
# life-extending
# China'seconomic
# anti-Davos
# 22,201bn
# ВЈ114
# 20,479
# stronger-than-expected
# 208m
# ВЈ111m
# Amusategui
# 'recession
# nine-strong
# over-regulation
# exchange-listed
# 12925

# %%
word2glove = {}
for w in word2idx:
    if w in glove_index_dict:
        g = w
    elif w.lower() in glove_index_dict:
        g = w.lower()
    else:
        continue
    word2glove[w] = g

# %%
w, idx = list(word2idx.items())[14099]
print(w, idx)
gidx = glove_index_dict[word2glove[w]]
print(gidx)
gweight = glove_embedding_weights[gidx,:].copy()
#print(gweight)
gweight /= np.sqrt(np.dot(gweight,gweight))
#print(gweight)
score = np.dot(normed_embedding[:len(vocabcount)-nb_unknown_words], gweight)
print(score)
embedding_idx = score.argmax()
print(embedding_idx)
s = score[embedding_idx]
embedding[embedding_idx]
# Out:
# unspecified 14101
# 9324
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-48-a8a4575ac0e2> in <module>()
#       7 gweight /= np.sqrt(np.dot(gweight,gweight))
#       8 #print(gweight)
# ----> 9 score = np.dot(normed_embedding[:len(vocabcount)-nb_unknown_words], gweight)
#      10 print(score)
#      11 embedding_idx = score.argmax()
#
# NameError: name 'normed_embedding' is not defined

# %%
for orig, sub, score in glove_match[-10:]:
    print(score, orig,'=>', idx2word[sub])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-49-48d2fdf56724> in <module>()
# ----> 1 for orig, sub, score in glove_match[-10:]:
#       2     print(score, orig,'=>', idx2word[sub])
#
# NameError: name 'glove_match' is not defined

# %%
word2idx['102']
# Out:
# 1908

# %%
inputs = [[word2idx[token] for token in nltk.word_tokenize(headline.replace(".", " . "))] for headline in heds]

# %%
outputs = [[word2idx[token] for token in nltk.word_tokenize(c.replace(".", " . "))] for c in contents]

# %%
import pickle
with open('data/inputs.pkl','wb') as fp:
    pickle.dump((embedding, idx2word, word2idx, []),fp,-1)

with open('data/outputs.data.pkl','wb') as fp:
    pickle.dump((inputs,outputs),fp,-1)

# %%
pri
